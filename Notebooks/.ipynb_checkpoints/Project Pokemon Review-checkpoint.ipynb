# %%
import pickle

import numpy as np 
import pandas as pd

import re 
import string 

from nltk.stem import WordNetLemmatizer

from sklearn.feature_extraction.text import CountVectorizer 

from langdetect import detect

from sklearn.decomposition import TruncatedSVD
from sklearn.decomposition import NMF
from sklearn.metrics.pairwise import cosine_similarity

# %%
with open('pokemon.pickle','rb') as read_file:
    df = pickle.load(read_file)

# %% [markdown]
# ### Data Cleaning

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2903 entries, 0 to 887
# Data columns (total 5 columns):
# name      2903 non-null object
# date      2903 non-null object
# rating    2903 non-null object
# review    2903 non-null object
# game      2903 non-null object
# dtypes: object(5)
# memory usage: 136.1+ KB

# %%
df['rating'] = df['rating'].astype(int)

# %%
### let's group the reviews by their ratings 
### following metacritics, 0 to 4 = negative, 5 to 7 mixed, 8 and above = positive 

def sentiment(x):
    if x > 7:
        return 'positive'
    if x < 5:
        return 'negative'
    else: return 'mixed'

df['sentiment'] = df['rating'].apply(lambda x:sentiment(x))

# %%
df['sentiment'].value_counts(normalize = True)
# Out:
# negative    0.610059
# positive    0.306235
# mixed       0.083707
# Name: sentiment, dtype: float64

# %%
### Some users posted on both pokemon sword and shield. 
### Did some checks, these reviews were the same  

df[df.duplicated('name')]
# Out:
#                name          date  rating  \
# 0         Metagrass  Nov 15, 2019       2
# 1     NintendoGuy64  Nov 15, 2019       0
# 4         Otonaburu  Nov 15, 2019       4
# 7     Gamermangamer  Nov 15, 2019       1
# 8           Fumetic  Nov 15, 2019       3
# ..              ...           ...     ...
# 871          HollyS  Nov 20, 2019       2
# 875       Lawrence7  Nov 20, 2019      10
# 877        sojasonk  Nov 20, 2019       1
# 879   KrakenOfPepsi  Nov 20, 2019       4
# 887  Mack_thge_Sack  Nov 21, 2019       0
#
#                                                 review    game sentiment
# 0    I have also done a review for Pokemon Sword, b...  shield  negative
# 1    As a lifelong fan of Pokemon games, I was ecst...  shield  negative
# 4    What should have been a giant leap to signific...  shield  negative
# 7    Was promised a game for "long time fans of the...  shield  negative
# 8    As these are largely the same games, I have pa...  shield  negative
# ..                                                 ...     ...       ...
# 871  Very short, bland and low quality Pokemon game...  shield  negative
# 875  For anyone debating whether they will like the...  shield  positive
# 877  Lazy writing, bad graphics, an absolute medioc...  shield  negative
# 879  Metacritic has a pretty small character limit ...  shield  negative
# 887  I'm going to state my points and not my emotio...  shield  negative
#
# [427 rows x 6 columns]

# %%
df.review[df['name'] == 'Mack_thge_Sack']
# Out:
# 1313    I'm going to state my points and not my emotio...
# 887     I'm going to state my points and not my emotio...
# Name: review, dtype: object

# %%
df.reset_index(inplace = True, drop = True)

# %%
#dropping duplicates 
df.drop_duplicates(subset='name', keep = 'first', inplace = True)

# %%
### cleaning the text 

def make_lower(text):
    return text.lower()

def remove_punctuation(text):
    return re.sub('[%s]' % re.escape(string.punctuation), '', text) 

def remove_digits(text):
    return re.sub('\d', '', text)

def clean_text(text):
    text = make_lower(text)
    text = remove_punctuation(text)
    text = remove_digits(text)
    return text

# %%
df['review'] = df['review'].apply(lambda x:clean_text(x))

# %%
#df['review'] = df['review'].apply(lambda x:remove_stopwords(str.split(x)))

# %%
### check for english words

# %%
def language_detection(x): 
    result = detect(x)
    if result == 'en':
        return x 
    else: return np.NaN 
    
df['review'] = df['review'].apply(lambda x:language_detection(x))

# %%
df.dropna(inplace = True)

# %%
lemmatizer=WordNetLemmatizer()

def lemmatize_words(x):
    lemmed_string = ''
    for word in x.split():
        lemmed_string = lemmed_string+' '+lemmatizer.lemmatize(word)  
    return lemmed_string.lstrip()

# %%
df['review'] = df['review'].apply(lambda x:lemmatize_words(x))

# %%
### remove stopwords text, using this method just incase I want to add more stopwords 
stop_words = nltk.corpus.stopwords.words('english')

# stop_words.extend(['come','order','try','go','get','make','drink','plate','dish','restaurant','place',
#                   'would','really','like','great','service','came','got'])

for word in stop_words:
    no_punct = remove_punctuation(word)
    if no_punct not in stop_words: 
        stop_words.append(no_punct)

# %%
stop_words
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'youre',
#  'youve',
#  'youll',
#  'youd',
#  'shes',
#  'thatll',
#  'dont',
#  'shouldve',
#  'arent',
#  'couldnt',
#  'didnt',
#  'doesnt',
#  'hadnt',
#  'hasnt',
#  'havent',
#  'isnt',
#  'mightnt',
#  'mustnt',
#  'neednt',
#  'shant',
#  'shouldnt',
#  'wasnt',
#  'werent',
#  'wont',
#  'wouldnt']

# %% [markdown]
# ## Splitting df by sentiment

# %%
negative = df[df['sentiment']=='negative']
mixed = df[df['sentiment']=='mixed']
positive = df[df['sentiment']=='postive']

# %%
negative
# Out:
#                  name          date  rating  \
# 0      ChocolateCrane  Nov 18, 2019       4
# 3     firstlovezombie  Nov 15, 2019       2
# 4        FilthyActs88  Nov 15, 2019       1
# 5          Ninjasuite  Nov 15, 2019       3
# 6        JustrzBustrz  Nov 15, 2019       2
# ...               ...           ...     ...
# 2889           Gonz04  Nov 20, 2019       0
# 2891        InTheMood  Nov 20, 2019       1
# 2893      Dreadwolf85  Nov 20, 2019       3
# 2897         Cotroneo  Nov 20, 2019       2
# 2901       Guandaside  Nov 21, 2019       0
#
#                                                  review    game sentiment
# 0     let u address the elephant in the room first t...   sword  negative
# 3     i really love pokemon which is why im so criti...   sword  negative
# 4     pokémon sword and shield is a game of pure med...   sword  negative
# 5     this is what happen if a company realize that ...   sword  negative
# 6     it’s an amazing feat how soulless this game fe...   sword  negative
# ...                                                 ...     ...       ...
# 2889  this game is so disappointing i literally ende...  shield  negative
# 2891  this is by far the worst pokémon game i have e...  shield  negative
# 2893  lazy game design pokemon still dont hit each o...  shield  negative
# 2897  if you consider this game a successor to the s...  shield  negative
# 2901  the game is good overall but there are two maj...  shield  negative
#
# [1229 rows x 6 columns]

# %%
vectorizer = CountVectorizer(stop_words=stop_words, 
                                   strip_accents = 'ascii', 
                                   token_pattern="\\b[a-z][a-z]+\\b")

# %%
doc_word = vectorizer.fit_transform(negative.review)
doc_word.shape
# Out:
# (1229, 8249)

# %%
pd.DataFrame(doc_word.toarray(), index=negative.review, columns=vectorizer.get_feature_names()).head(10)
# Out:
#                                                     aaa  ab  abandoned  \
# review
# let u address the elephant in the room first th...    0   0          0
# i really love pokemon which is why im so critic...    0   0          0
# pokémon sword and shield is a game of pure medi...    0   0          0
# this is what happen if a company realize that t...    0   0          0
# it’s an amazing feat how soulless this game fee...    0   0          0
# i really wish the game were good i dont leave t...    0   0          0
# the game is full of graphical glitch it is shor...    0   0          0
# pokemon sword and shield boast expansive landsc...    0   0          0
# easiest game ive ever played unnecesary cut of ...    0   0          0
# let me just get this outta way first i’m a mass...    0   0          0
#
#                                                     abhorrent  abilites  \
# review
# let u address the elephant in the room first th...          0         0
# i really love pokemon which is why im so critic...          0         0
# pokémon sword and shield is a game of pure medi...          1         0
# this is what happen if a company realize that t...          0         0
# it’s an amazing feat how soulless this game fee...          0         0
# i really wish the game were good i dont leave t...          0         0
# the game is full of graphical glitch it is shor...          0         0
# pokemon sword and shield boast expansive landsc...          0         0
# easiest game ive ever played unnecesary cut of ...          0         0
# let me just get this outta way first i’m a mass...          0         0
#
#                                                     ability  abismal  abit  \
# review
# let u address the elephant in the room first th...        0        0     0
# i really love pokemon which is why im so critic...        0        0     0
# pokémon sword and shield is a game of pure medi...        0        0     0
# this is what happen if a company realize that t...        0        0     0
# it’s an amazing feat how soulless this game fee...        0        0     0
# i really wish the game were good i dont leave t...        0        0     0
# the game is full of graphical glitch it is shor...        0        0     0
# pokemon sword and shield boast expansive landsc...        0        0     0
# easiest game ive ever played unnecesary cut of ...        0        0     0
# let me just get this outta way first i’m a mass...        0        0     0
#
#                                                     abject  able  ...  zero  \
# review                                                            ...
# let u address the elephant in the room first th...       0     0  ...     0
# i really love pokemon which is why im so critic...       0     0  ...     0
# pokémon sword and shield is a game of pure medi...       0     0  ...     0
# this is what happen if a company realize that t...       0     0  ...     0
# it’s an amazing feat how soulless this game fee...       0     0  ...     0
# i really wish the game were good i dont leave t...       0     0  ...     0
# the game is full of graphical glitch it is shor...       0     0  ...     0
# pokemon sword and shield boast expansive landsc...       0     0  ...     0
# easiest game ive ever played unnecesary cut of ...       0     0  ...     0
# let me just get this outta way first i’m a mass...       0     0  ...     0
#
#                                                     zilch  zmove  zmoves  \
# review
# let u address the elephant in the room first th...      0      0       0
# i really love pokemon which is why im so critic...      0      0       0
# pokémon sword and shield is a game of pure medi...      0      0       0
# this is what happen if a company realize that t...      0      0       0
# it’s an amazing feat how soulless this game fee...      0      0       0
# i really wish the game were good i dont leave t...      0      0       1
# the game is full of graphical glitch it is shor...      0      0       0
# pokemon sword and shield boast expansive landsc...      0      0       0
# easiest game ive ever played unnecesary cut of ...      0      0       0
# let me just get this outta way first i’m a mass...      0      0       0
#
#                                                     zombie  zombielike  zone  \
# review
# let u address the elephant in the room first th...       0           0     0
# i really love pokemon which is why im so critic...       0           0     0
# pokémon sword and shield is a game of pure medi...       0           0     0
# this is what happen if a company realize that t...       0           0     0
# it’s an amazing feat how soulless this game fee...       0           0     0
# i really wish the game were good i dont leave t...       0           0     0
# the game is full of graphical glitch it is shor...       0           0     0
# pokemon sword and shield boast expansive landsc...       0           0     0
# easiest game ive ever played unnecesary cut of ...       0           0     0
# let me just get this outta way first i’m a mass...       0           0     0
#
#                                                     zoo  zoomed  zootopia
# review
# let u address the elephant in the room first th...    0       0         0
# i really love pokemon which is why im so critic...    0       0         0
# pokémon sword and shield is a game of pure medi...    0       0         0
# this is what happen if a company realize that t...    0       0         0
# it’s an amazing feat how soulless this game fee...    0       0         0
# i really wish the game were good i dont leave t...    0       0         0
# the game is full of graphical glitch it is shor...    0       0         0
# pokemon sword and shield boast expansive landsc...    0       0         0
# easiest game ive ever played unnecesary cut of ...    0       0         0
# let me just get this outta way first i’m a mass...    0       0         0
#
# [10 rows x 8249 columns]

# %% [markdown]
# ## LSA

# %%
lsa = TruncatedSVD(2)
doc_topic = lsa.fit_transform(doc_word)
lsa.explained_variance_ratio_
# Out:
# array([0.30478872, 0.03496874])

# %%
topic_word = pd.DataFrame(lsa.components_.round(3),
             index = ["component_1","component_2"],
             columns = vectorizer.get_feature_names())
topic_word
# Out:
#                aaa     ab  abandoned  abhorrent  abilites  ability  abismal  \
# component_1  0.002  0.000      0.001        0.0     0.001    0.008      0.0
# component_2 -0.001  0.001     -0.001        0.0     0.003    0.007      0.0
#
#              abit  abject   able  ...   zero  zilch  zmove  zmoves  zombie  \
# component_1   0.0   0.000  0.013  ...  0.002    0.0  0.000   0.009     0.0
# component_2  -0.0   0.001  0.005  ...  0.000    0.0  0.002   0.015    -0.0
#
#              zombielike   zone  zoo  zoomed  zootopia
# component_1       0.000  0.002  0.0   0.000       0.0
# component_2      -0.001 -0.002  0.0   0.001       0.0
#
# [2 rows x 8249 columns]

# %%
def display_topics(model, feature_names, no_top_words, topic_names=None):
    for ix, topic in enumerate(model.components_):
        if not topic_names or not topic_names[ix]:
            print("\nTopic ", ix)
        else:
            print("\nTopic: '",topic_names[ix],"'")
        print(", ".join([feature_names[i]
                        for i in topic.argsort()[:-no_top_words - 1:-1]]))

# %%
display_topics(lsa, vectorizer.get_feature_names(), 10)
# Out:
# Topic  0
# game, pokemon, like, wa, even, new, animation, battle, time, ha
#
# Topic  1
# pokemon, like, battle, new, area, feel, wild, look, animation, also

# %%
Vt = pd.DataFrame(doc_topic.round(5),
             index = negative.review,
             columns = ["component_1","component_2" ])
Vt
# Out:
#                                                     component_1  component_2
# review
# let u address the elephant in the room first th...     20.66620     -1.46243
# i really love pokemon which is why im so critic...     13.54680      4.56069
# pokémon sword and shield is a game of pure medi...      9.59140     -2.87781
# this is what happen if a company realize that t...      4.20497      3.65870
# it’s an amazing feat how soulless this game fee...      6.50699     -0.65592
# ...                                                         ...          ...
# this game is so disappointing i literally ended...      2.01039     -0.52267
# this is by far the worst pokémon game i have ev...      9.80304      2.78295
# lazy game design pokemon still dont hit each ot...      2.94132      0.58687
# if you consider this game a successor to the sp...      4.59864      2.36238
# the game is good overall but there are two majo...      2.92003     -0.07110
#
# [1229 rows x 2 columns]

# %%
nmf_model = NMF(2)
doc_topic_nmf = nmf_model.fit_transform(doc_word)

# %%
display_topics(nmf_model, vectorizer.get_feature_names(), 10)
# Out:
# Topic  0
# game, wa, ha, fan, content, even, pokemon, switch, good, much
#
# Topic  1
# pokemon, like, game, battle, new, area, animation, feel, even, wa

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-91-5587a7eaed90> in <module>
# ----> 1 nmf.explained_variance_ratio_
#
# NameError: name 'nmf' is not defined
