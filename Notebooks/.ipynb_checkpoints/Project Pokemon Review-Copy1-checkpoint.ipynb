# %% [markdown]
# ### Importing Packages

# %%
import pickle

import numpy as np 
import pandas as pd

import re 
import string 

import nltk
#from nltk.stem import WordNetLemmatizer

from sklearn.feature_extraction.text import CountVectorizer 

from langdetect import detect

from sklearn.decomposition import TruncatedSVD
from sklearn.decomposition import NMF
# from sklearn.metrics.pairwise import cosine_similarity

import spacy

import gensim
from gensim import corpora, models, similarities, matutils

# %% [markdown]
# ## Opening Scrapped Data

# %%
with open('pokemon.pickle','rb') as read_file:
    df = pickle.load(read_file)

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3261 entries, 0 to 558
# Data columns (total 5 columns):
# name      3261 non-null object
# date      3261 non-null object
# rating    3261 non-null object
# review    3261 non-null object
# game      3261 non-null object
# dtypes: object(5)
# memory usage: 152.9+ KB

# %%
df['rating'] = df['rating'].astype(int)

# %%
### let's group the reviews by their ratings 
### following metacritics, 0 to 4 = negative, 5 to 7 mixed, 8 and above = positive 

def sentiment(x):
    if x > 7:
        return 'positive'
    if x < 5:
        return 'negative'
    else: return 'mixed'

df['sentiment'] = df['rating'].apply(lambda x:sentiment(x))

# %%
df['sentiment'].value_counts(normalize = True)
# Out:
# negative    0.591843
# positive    0.311254
# mixed       0.096903
# Name: sentiment, dtype: float64

# %%
### Some users posted on both pokemon sword and shield. 
### Did some checks, these reviews were the same  

df[df.duplicated('name')]
# Out:
#                name          date  rating  \
# 0    ChocolateCrane  Nov 18, 2019       4
# 4    InsaneSeishiro  Nov 23, 2019       3
# 6       theoftime12  Nov 15, 2019       2
# 10          Nikox96  Nov 15, 2019       1
# 19            Rardo  Nov 15, 2019       4
# ..              ...           ...     ...
# 530         DarkGio  Nov 22, 2019       6
# 542         Speedie  Nov 24, 2019       7
# 543           Lovio  Nov 24, 2019       6
# 547       Edumiroku  Nov 24, 2019       3
# 553       GarrMoose  Nov 25, 2019       5
#
#                                                 review   game sentiment
# 0    Let us address the elephant in the room first....  sword  negative
# 4    This game is a rushjob.\r That said, not all t...  sword  negative
# 6    Un juego gráficamente muy inferior la les go P...  sword  negative
# 10   Deja mucho que desear. Historia lenta y mala, ...  sword  negative
# 19   To be honest this game is disappointing, don’t...  sword  negative
# ..                                                 ...    ...       ...
# 530  Look,this game isn't as bad as some people say...  sword     mixed
# 542  If you're looking to compare this game to the ...  sword     mixed
# 543  I wish to start out by saying that I have 100%...  sword     mixed
# 547  I enjoyed the Game, however, I don't wanna giv...  sword  negative
# 553  The move onto the Switch brought forth much fo...  sword     mixed
#
# [467 rows x 6 columns]

# %%
df.review[df['name'] == 'Mack_thge_Sack']
# Out:
# 962     I'm going to state my points and not my emotio...
# 1313    I'm going to state my points and not my emotio...
# Name: review, dtype: object

# %%
df.reset_index(inplace = True, drop = True)

# %%
### dropping duplicate names 
df.drop_duplicates(subset='name', keep = 'first', inplace = True)

# %%
### detect review language and returns NaN if not english 
def language_detection(x): 
    result = detect(x)
    if result == 'en':
        return x 
    else: return np.NaN 
    
df['review'] = df['review'].apply(lambda x:language_detection(x))

### drop reviews that are not in english 
df.dropna(inplace = True)

# %%
#df.to_pickle('clean_dataset.pickle')

# %% [markdown]
# ### Text Cleaning

# %%
with open('clean_dataset.pickle','rb') as read_file:
    df = pickle.load(read_file)

# %%
df['review'][3]
# Out:
# 'This game feels like a port from the 3DS, not a new game built for the systemWhile many fans will enjoy these games, for me, it feels like the same game as the last 7 Generations with a Graphical upgrade that is Impressive compared to the past 3DS games but quite bad compared to other Switch games'

# %%
# def remove_r(text):
#     return text.replace('\r','')

# df['review'] = df['review'].apply(lambda x:remove_r(x))

# %%
def strip_whitespace(text):
    return text.strip()

def make_lower(text):
    return text.lower()

def remove_digits(text):
    return re.sub('\d', '', text)

def remove_punctuation(text):
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text) 
    return re.sub(r'[^\w\s]', '', text)

#df['review'] = df['review'].apply(lambda x:remove_punctuation(x))

def clean_text(text):
    text = strip_whitespace(text)
    text = make_lower(text)
    text = remove_punctuation(text)
    text = remove_digits(text)
    return text

# %%
df['review'] = df['review'].apply(lambda x:clean_text(x))

# %%
#df['review'] = df['review'].apply(lambda x:remove_stopwords(str.split(x)))

# %%
# lemmatizer=WordNetLemmatizer()

# def lemmatize_words(x):
#     lemmed_string = ''
#     for word in x.split():
#         lemmed_string = lemmed_string+' '+lemmatizer.lemmatize(word)  
#     return lemmed_string.lstrip()

sp = spacy.load('en_core_web_sm')

def lemmatize_words(text, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):
    text = sp(text)
    lemmed_string =''
    for word in text:
        if word.pos_ in allowed_postags:
            if word.lemma_ == '-PRON-':
                word.lemma_ = word.orth_ # change the string representation
                word.lemma = word.orth #
            else: lemmed_string = lemmed_string+' '+word.lemma_
    return lemmed_string.lstrip()

# def lemmatization(texts, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):
#     """https://spacy.io/api/annotation"""
#     texts_out = []
#     for sent in texts:
#         doc = nlp(" ".join(sent)) 
#         texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
#     return texts_out

# %%
df['review'] = df['review'].apply(lambda x:lemmatize_words(x, allowed_postags=['NOUN', 'VERB']))

# %%
# # Build the bigram and trigram models - reference: https://www.machinelearningplus.com/nlp/topic-modeling-gensim-python/
# data = []
# for entry in df.review:
#     data.append(entry.split())

# bigram = gensim.models.Phrases(data, min_count=5, threshold=5) # higher threshold fewer phrases.
# trigram = gensim.models.Phrases(bigram[data], threshold=5)  

# bigram_mod = gensim.models.phrases.Phraser(bigram)
# trigram_mod = gensim.models.phrases.Phraser(trigram)

# def make_bigrams(x):
#     text = bigram_mod[x.split()] 
#     grammed_string = ''
#     for word in text: 
#         grammed_string = grammed_string+' '+word 
#     return grammed_string 

# def make_trigrams(x):
#     text = trigram_mod[bigram_mod[x.split()] ] 
#     grammed_string = ''
#     for word in text: 
#         grammed_string = grammed_string+' '+word 
#     return grammed_string

# %%
# df['review'] = df['review'].apply(lambda x:make_bigrams(x))  
# df['review'] = df['review'].apply(lambda x:make_trigrams(x))

# %%
df.to_pickle('dfclean_b4rare.pickle') ### cleaned text and lemmatised

# %%
with open('dfclean_b4rare.pickle','rb') as read_file:
    df = pickle.load(read_file)

# %%
# ### create list of rare words by filtering on word counts
freq = pd.DataFrame(df.review.str.split(expand=True).stack().value_counts())
freq = freq[freq<11]
freq.dropna(inplace = True)
freq.reset_index(inplace = True)
freq = freq['index'].to_list()

# %%
freq
# Out:
# ['chore',
#  'playtime',
#  'pain',
#  'barebone',
#  'chairman',
#  'deadline',
#  'storage',
#  'period',
#  'seek',
#  'oppose',
#  'minigame',
#  'elephant',
#  'phone',
#  'forgive',
#  'answer',
#  'casual',
#  'movie',
#  'fade',
#  'star',
#  'glare',
#  'customize',
#  'extent',
#  'eevee',
#  'business',
#  'shinie',
#  'creator',
#  'luster',
#  'eternatus',
#  'magic',
#  'cook',
#  'masterpiece',
#  'quantity',
#  'mine',
#  'up',
#  'autosave',
#  'appearance',
#  'department',
#  'angle',
#  'land',
#  'plague',
#  'emphasis',
#  'inclusion',
#  'dip',
#  'scream',
#  'pocket',
#  'dlc',
#  're',
#  'negativity',
#  'subscription',
#  'newcomer',
#  'split',
#  'dialog',
#  'breeze',
#  'integrate',
#  'fish',
#  'week',
#  'scorbunny',
#  'pack',
#  'definition',
#  'redo',
#  'door',
#  'parent',
#  'creation',
#  'reality',
#  'holding',
#  'message',
#  'express',
#  'damn',
#  'relate',
#  'mansion',
#  'yesterday',
#  'red',
#  'lay',
#  'memory',
#  'proof',
#  'resemble',
#  'protagonist',
#  'laugh',
#  'betray',
#  'wooloo',
#  'package',
#  'ease',
#  'semblance',
#  'eat',
#  'burn',
#  'shelf',
#  'overshadow',
#  'tie',
#  'attach',
#  'overpower',
#  'yamper',
#  'upset',
#  'reasoning',
#  'downside',
#  'darkness',
#  'ass',
#  'stage',
#  'craft',
#  'revisit',
#  'island',
#  'corviknight',
#  'argument',
#  'grace',
#  'scaling',
#  'feedback',
#  'swap',
#  'edition',
#  'catching',
#  'moveset',
#  'nonsense',
#  'teach',
#  'maintain',
#  'restriction',
#  'letdown',
#  'light',
#  'cake',
#  'flop',
#  'cater',
#  'master',
#  'stone',
#  'edit',
#  'a',
#  'explanation',
#  'fidelity',
#  'variant',
#  'youtube',
#  'partner',
#  'rail',
#  'cross',
#  'narrative',
#  'impression',
#  'masuda',
#  'filter',
#  'conversation',
#  'apply',
#  'meh',
#  'scenario',
#  'establish',
#  'discount',
#  'accomplish',
#  'contrast',
#  'frustrate',
#  'coat',
#  'planet',
#  'absence',
#  'sign',
#  'revenue',
#  'genius',
#  'basis',
#  'nail',
#  'addict',
#  'cookie',
#  'sequel',
#  'rely',
#  'baffle',
#  'distract',
#  'clear',
#  'advance',
#  'pool',
#  'tho',
#  'revive',
#  'rotation',
#  'snap',
#  'optimization',
#  'ev',
#  'lesson',
#  'suit',
#  'pier',
#  'buff',
#  'halfbake',
#  'counter',
#  'welcome',
#  'bond',
#  'rank',
#  'replayability',
#  'usd',
#  'hiccup',
#  'consist',
#  'loading',
#  'screw',
#  'lol',
#  'rid',
#  'contest',
#  'obtain',
#  'toy',
#  'energy',
#  'god',
#  'copypaste',
#  'dozen',
#  'framedrop',
#  'feed',
#  'debut',
#  'fighting',
#  'xy',
#  'cloud',
#  'crush',
#  'linearity',
#  'incentive',
#  'invest',
#  'announcement',
#  'surf',
#  'clip',
#  'cooking',
#  'in',
#  'oneshot',
#  'tier',
#  'brick',
#  'bomber',
#  'entirety',
#  'task',
#  'botw',
#  'e',
#  'structure',
#  'statement',
#  'skin',
#  'warrant',
#  'importance',
#  'succeed',
#  'bede',
#  'culture',
#  'borrow',
#  'boot',
#  'afford',
#  'elite',
#  'participate',
#  'being',
#  'shift',
#  'objective',
#  'bricke',
#  'spam',
#  'student',
#  'flow',
#  'drama',
#  'adore',
#  'enhance',
#  'awaken',
#  'bump',
#  'open',
#  'spinoff',
#  'tms',
#  'rocket',
#  'discuss',
#  'director',
#  'represent',
#  'tad',
#  'toggle',
#  'image',
#  'clone',
#  'hack',
#  'advice',
#  'root',
#  'arrive',
#  'sobble',
#  'roadblock',
#  'predict',
#  'traverse',
#  'recipe',
#  'linear',
#  'overlevelle',
#  'completion',
#  'enable',
#  'substance',
#  'middle',
#  'instrument',
#  'idiot',
#  'lineup',
#  'dishearten',
#  'curve',
#  'handholde',
#  'clothing',
#  'capacity',
#  'spectacle',
#  'hook',
#  'communicate',
#  'switchs',
#  'growth',
#  'profit',
#  'disgrace',
#  'remodel',
#  'glitche',
#  'rain',
#  'server',
#  'heck',
#  'phase',
#  'topic',
#  'cartridge',
#  'egg',
#  'compete',
#  'v',
#  'headbutt',
#  'episode',
#  'average',
#  'disregard',
#  'reflect',
#  'hint',
#  'exclusion',
#  'click',
#  'piss',
#  'x',
#  'spread',
#  'proceed',
#  'slew',
#  'demand',
#  'culling',
#  'healing',
#  'swim',
#  'cutter',
#  'adjust',
#  'tweak',
#  'embarrass',
#  'aswell',
#  'interruption',
#  'handholdy',
#  'fee',
#  'breaker',
#  'instalment',
#  'bland',
#  'breathtake',
#  'chunk',
#  'terrain',
#  'lover',
#  'accord',
#  'erase',
#  'practice',
#  'piece',
#  'audio',
#  'fence',
#  'chronicle',
#  'eeveelution',
#  'complexity',
#  'research',
#  'nand',
#  'h',
#  'earth',
#  'mountain',
#  'member',
#  'maze',
#  'single',
#  'icon',
#  'evil',
#  'inability',
#  'gamestop',
#  'vary',
#  'stranger',
#  'sheild',
#  'old',
#  'fallout',
#  'bias',
#  'nationaldex',
#  'floor',
#  'generate',
#  'slide',
#  'novelty',
#  'sweep',
#  'making',
#  'nitpick',
#  'bottom',
#  'round',
#  'warning',
#  'colour',
#  'dude',
#  'menu',
#  'interview',
#  'mom',
#  'grant',
#  'anticipate',
#  'acting',
#  'disconnect',
#  'playstation',
#  'ign',
#  'cartoon',
#  'stream',
#  'animal',
#  'robot',
#  'spike',
#  'surface',
#  'trip',
#  'ending',
#  'tone',
#  'upscale',
#  'mediocre',
#  'wrong',
#  'advise',
#  'status',
#  'host',
#  'immerse',
#  'whip',
#  'sandstorm',
#  'connection',
#  'trigger',
#  'actor',
#  'critique',
#  'eliminate',
#  'material',
#  'op',
#  'girl',
#  'coop',
#  'detract',
#  'professor',
#  'peak',
#  'dog',
#  'boycott',
#  'shell',
#  'grookey',
#  'onix',
#  'shape',
#  'schedule',
#  'shade',
#  'impact',
#  'slog',
#  'lobby',
#  'fool',
#  'mile',
#  'andor',
#  'define',
#  'tackle',
#  'grade',
#  'acknowledge',
#  'exclusive',
#  'cutte',
#  'controller',
#  'bet',
#  'glorify',
#  'thinking',
#  'fishing',
#  'scope',
#  'tyranitar',
#  'scrap',
#  'scheme',
#  'gba',
#  'son',
#  'interface',
#  'gale',
#  'dragon',
#  'human',
#  'worth',
#  'gamebreake',
#  'percent',
#  'nickname',
#  'gift',
#  'ad',
#  'pretend',
#  'dare',
#  'key',
#  'omega',
#  'challenging',
#  'teleport',
#  'deny',
#  'potion',
#  'aesthetic',
#  'grafic',
#  'school',
#  'intreste',
#  'boil',
#  'unfinishe',
#  'settle',
#  'steal',
#  'alternative',
#  'wall',
#  'condition',
#  'balancing',
#  'wing',
#  'faith',
#  'book',
#  'reference',
#  'food',
#  'showcase',
#  'decrease',
#  'circle',
#  'summarize',
#  'shock',
#  'inspire',
#  'pixelate',
#  'estimate',
#  'baseline',
#  'legendary',
#  'elevator',
#  'merchandise',
#  'favour',
#  'war',
#  'pity',
#  'nope',
#  'data',
#  'dumpster',
#  'stranding',
#  'weight',
#  'salt',
#  'input',
#  'imagination',
#  'farm',
#  'digimon',
#  'fraction',
#  'compose',
#  'tear',
#  'irritate',
#  'corruption',
#  'arc',
#  'blizzard',
#  'criticize',
#  'bummer',
#  'category',
#  'fav',
#  'reboot',
#  'preordere',
#  'reskin',
#  'inconsistency',
#  'consequence',
#  'lacking',
#  'disadvantage',
#  'disrespect',
#  'c',
#  'library',
#  'assurance',
#  'segment',
#  'wind',
#  'oven',
#  'dinamaxing',
#  'car',
#  'ooze',
#  'stretch',
#  'outfit',
#  'glass',
#  'repackage',
#  'gap',
#  'simplicity',
#  'stutter',
#  'sky',
#  'wifi',
#  'software',
#  'hub',
#  'reminder',
#  'entertainment',
#  'lame',
#  'thumb',
#  'children',
#  'hover',
#  'speaking',
#  'trial',
#  'demo',
#  'thankyougamefreak',
#  'strength',
#  'crystal',
#  'dataminer',
#  'pkm',
#  'guide',
#  'disgust',
#  'sonority',
#  'outlet',
#  'gate',
#  'videogame',
#  'wash',
#  'recognition',
#  'cancel',
#  'warn',
#  'k',
#  'lifeless',
#  'overall',
#  'buildup',
#  'blame',
#  'classic',
#  'anger',
#  'barrier',
#  'escape',
#  'halfway',
#  'confuse',
#  'digit',
#  'carbon',
#  'beta',
#  'bird',
#  'basic',
#  'pad',
#  'longevity',
#  'spamme',
#  'cent',
#  'feat',
#  'offering',
#  'rematch',
#  'low',
#  'counterpart',
#  'custom',
#  'ban',
#  'dedicate',
#  'companion',
#  'cull',
#  'sumo',
#  'sadden',
#  'squander',
#  'lying',
#  'fashion',
#  'pander',
#  'disagree',
#  'debate',
#  'spit',
#  'festival',
#  'thrill',
#  'satisfaction',
#  'spite',
#  'merit',
#  'bruh',
#  'brim',
#  'justification',
#  'react',
#  'investment',
#  'proportion',
#  'ok',
#  'hgss',
#  'billion',
#  'response',
#  'dress',
#  'popup',
#  'trope',
#  'shoot',
#  'conflict',
#  'dragapult',
#  'talking',
#  'flap',
#  'bonus',
#  'ear',
#  'recognize',
#  'metagame',
#  'championship',
#  'resume',
#  'park',
#  'trait',
#  'simulator',
#  'cmon',
#  'cheat',
#  'sway',
#  'annoyance',
#  'makeup',
#  'wise',
#  'overprice',
#  'tip',
#  'out',
#  'success',
#  'ppl',
#  'plain',
#  'plus',
#  'ripple',
#  'mystery',
#  'indie',
#  'leon',
#  'knowledge',
#  'accessibility',
#  'witness',
#  'honesty',
#  'hairstyle',
#  'reading',
#  'sister',
#  'co',
#  'hinder',
#  'priority',
#  'crime',
#  'window',
#  'variation',
#  'flagship',
#  'unpolishe',
#  'holdy',
#  'enthusiasm',
#  'lower',
#  'pr',
#  'overwhelm',
#  'galore',
#  'accompany',
#  'rabbit',
#  'skull',
#  'hurry',
#  'sorry',
#  'bogge',
#  'consume',
#  'promote',
#  'coast',
#  'vargene',
#  'perfect',
#  'duration',
#  'random',
#  'gamei',
#  'experiment',
#  'paywall',
#  'ps',
#  'brainless',
#  'bind',
#  'discovery',
#  'puedo',
#  'street',
#  'exaggeration',
#  'expose',
#  'gem',
#  'motion',
#  'demographic',
#  'surpass',
#  'tune',
#  'award',
#  'tail',
#  'indicate',
#  'tempt',
#  'soccer',
#  'clock',
#  'sub',
#  'means',
#  'standpoint',
#  'splatoon',
#  'roar',
#  'resolve',
#  'pikachueevee',
#  'thousand',
#  'quarter',
#  'hunter',
#  'retain',
#  'clean',
#  'tech',
#  'behavior',
#  'quit',
#  'slash',
#  'production',
#  'compliment',
#  'polygon',
#  'source',
#  'evidence',
#  'backstory',
#  'cavern',
#  'ponyta',
#  'streamer',
#  'implementation',
#  'english',
#  'philosophy',
#  'clash',
#  'embarrassment',
#  'hole',
#  'tactic',
#  'witcher',
#  'fruition',
#  'datamine',
#  'considering',
#  'redblue',
#  'judgment',
#  'insert',
#  'commit',
#  'myriad',
#  'bridge',
#  'overlevel',
#  'board',
#  'sentence',
#  'sm',
#  'witch',
#  'jerk',
#  'everyone',
#  'simplification',
#  'notch',
#  'network',
#  'eshop',
#  'giant',
#  'burst',
#  'wave',
#  'squirtle',
#  'vgc',
#  'technology',
#  'disservice',
#  'gameboy',
#  'pokèmon',
#  'imply',
#  'redone',
#  'ship',
#  'junk',
#  'stress',
#  'pointless',
#  'default',
#  'shoehorn',
#  'rope',
#  'rendering',
#  'balloon',
#  'noise',
#  'expense',
#  'select',
#  'communication',
#  'uniform',
#  'pkmn',
#  'flicker',
#  'verdict',
#  'install',
#  'nonexistent',
#  'deviation',
#  'script',
#  'boast',
#  'extension',
#  'apple',
#  'depress',
#  'abuse',
#  'liar',
#  'vitamin',
#  'steel',
#  'rd',
#  'manpower',
#  'incorporate',
#  'exposition',
#  'mindset',
#  'pattern',
#  'amaze',
#  'corporation',
#  'layout',
#  'exploit',
#  'pokemom',
#  'outrage',
#  'discard',
#  'mainserie',
#  'steamroll',
#  'availability',
#  'recicle',
#  'tent',
#  'theory',
#  'health',
#  'beast',
#  'transport',
#  'dissapointment',
#  'rob',
#  'convince',
#  'attract',
#  'fine',
#  'row',
#  'dexcut',
#  'summary',
#  'derive',
#  'delivery',
#  'birth',
#  'boat',
#  'direct',
#  'lusamine',
#  'rubbish',
#  'wrap',
#  'billionaire',
#  'pun',
#  'tout',
#  'ensure',
#  'gather',
#  'stamp',
#  'reccomend',
#  'drift',
#  'fulfil',
#  'stare',
#  'tendency',
#  'offense',
#  'crack',
#  'interactivity',
#  'chapter',
#  'disable',
#  'nightmare',
#  'dread',
#  'portray',
#  'horrid',
#  'buying',
#  'exit',
#  'mewtwo',
#  'tpci',
#  'tool',
#  'maingame',
#  'fund',
#  'motostoke',
#  'revolve',
#  'close',
#  'role',
#  'groundbreake',
#  'courage',
#  'mount',
#  'page',
#  'sequence',
#  'lean',
#  'mood',
#  'equivalent',
#  'playerbase',
#  'slogan',
#  'outta',
#  'connectivity',
#  'dedication',
#  'ally',
#  'bloat',
#  'kinda',
#  'soulsilver',
#  'slow',
#  'expansion',
#  'divide',
#  'abandon',
#  'simplify',
#  'asse',
#  'policy',
#  'doom',
#  'relax',
#  'outsource',
#  'protection',
#  'barren',
#  'incompetence',
#  'animator',
#  'inhabit',
#  'unlock',
#  'daughter',
#  'website',
#  'playstyle',
#  'compel',
#  'heartgold',
#  'sight',
#  'running',
#  'mmo',
#  'family',
#  'negate',
#  'lvls',
#  'device',
#  'mar',
#  'finger',
#  'axis',
#  'record',
#  'storywise',
#  'straw',
#  'suspect',
#  'lowre',
#  'glitchy',
#  'dishonesty',
#  'niche',
#  'representation',
#  'cute',
#  'onrail',
#  'wingull',
#  'discord',
#  'tolerate',
#  'tm',
#  'reside',
#  'reflection',
#  'railroading',
#  'recreate',
#  'language',
#  'please',
#  'smile',
#  'dig',
#  'coffin',
#  'stuttering',
#  'prediction',
#  'machine',
#  'rinse',
#  'powerhouse',
#  'unit',
#  'norm',
#  'punch',
#  'pallet',
#  'wanna',
#  'omg',
#  'motive',
#  'afterthought',
#  'pokmeon',
#  'heap',
#  'fulfill',
#  'captivate',
#  'rework',
#  'boredom',
#  'glory',
#  'jag',
#  'gane',
#  'poof',
#  'pathway',
#  'approve',
#  'overblow',
#  'buyer',
#  'dub',
#  'transparency',
#  'cartoony',
#  'breathe',
#  'pokemonthis',
#  'pokefan',
#  'presence',
#  'realism',
#  'prelaunch',
#  'meaning',
#  'newbie',
#  'reek',
#  'gigamaxe',
#  'spark',
#  'whine',
#  'motif',
#  'reset',
#  'infuriate',
#  'leadership',
#  'redefine',
#  'influence',
#  'omission',
#  'composer',
#  'apologize',
#  'spout',
#  'garchomp',
#  'detriment',
#  'duo',
#  'foundation',
#  'overabundance',
#  'entity',
#  'restart',
#  'alter',
#  'cacophony',
#  'butt',
#  'roku',
#  'welp',
#  'deem',
#  'gameand',
#  'candle',
#  'beginner',
#  ...]

# %%
def remove_words(text,wordlist):
    for word in wordlist:
        if word in text:
            text = re.sub(r'\b{}\b'.format(word), '', text)  
    return text

df['review'] = df['review'].apply(lambda x:remove_words(x,freq))

# %%
# ### checking high frequency words to add to stopword list 
freq = pd.DataFrame(df.review.str.split(expand=True).stack().value_counts())

# %%
pd.set_option('display.max_rows', 1000)
freq.head(30)
# Out:
#               0
# game       9421
# pokemon    3141
# can        1437
# make       1349
# play       1207
# pokémon    1086
# feel       1011
# area        963
# go          948
# animation   946
# time        922
# battle      916
# look        908
# will        901
# story       882
# have        864
# would       853
# be          791
# graphic     772
# get         709
# cut         679
# s           626
# lot         615
# fan         591
# thing       585
# say         569
# see         566
# give        547
# could       539
# series      539

# %%
df.to_pickle('dfclean.pickle')

# with open('dfclean.pickle','rb') as read_file:
#      df = pickle.load(read_file)

# %%
# def replace_word(text,word,replacement):
#     return re.sub(r'\b{}\b'.format(word), replacement, text) 

# df['review'] = df['review'].apply(lambda x:replace_word(x,'game_freak','gamefreak'))

# %%
#freq = pd.DataFrame(df.review.str.split(expand=True).stack().value_counts())

# %%
### remove stopwords text, using this method just incase I want to add more stopwords 
nltk_stop_words = nltk.corpus.stopwords.words('english')

stop_words =  list(spacy.lang.en.stop_words.STOP_WORDS)
stop_words.extend(['game','pokemon','pokémon', 'play','make'])

                   
                   #'animation','area','battle', 'sword','shield']) 

                   #'play', 'review'])

#'battle','new','bad','good', 'play', 'more'])

for word in stop_words:
    if word in stop_words: 
        continue
    else: stop_words.append(word)

for word in stop_words:
    no_punct = remove_punctuation(word)
    if no_punct not in stop_words: 
        stop_words.append(no_punct)

# %% [markdown]
# ## Splitting df by sentiment

# %%
negative = df[df['sentiment']=='negative']
mixed = df[df['sentiment']=='mixed']
positive = df[df['sentiment']=='postive']

# %%
negative
# Out:
#                 name          date  rating  \
# 0          Otonaburu  Nov 15, 2019       4
# 1          Metagrass  Nov 15, 2019       2
# 2            Drakhis  Nov 15, 2019       2
# 3            Ok_Then  Nov 15, 2019       4
# 4      NintendoGuy64  Nov 15, 2019       0
# ...              ...           ...     ...
# 3224      moosbuckel  Nov 21, 2019       1
# 3227       Bashbach1  Nov 21, 2019       4
# 3233  Eduardobritola  Nov 22, 2019       3
# 3250       Potteriti  Nov 24, 2019       2
# 3251        NellTull  Nov 25, 2019       0
#
#                                                  review    game sentiment
# 0     should leap hardware feel port feature improve...  shield  negative
# 1     do review sword version game have copy game ca...  shield  negative
# 2     fan game lot problem turn  game can bug wipe  ...  shield  negative
# 3     game feel port game build  fan will enjoy game...  shield  negative
# 4     fan game pokemon game announce switch home con...  shield  negative
# ...                                                 ...     ...       ...
# 3224  play hour game bore story route explore game w...   sword  negative
# 3227  know beginning game freak run idea pokémon  re...   sword  negative
# 3233            world design experience can  game make    sword  negative
# 3250                              design pokémon let go   sword  negative
# 3251  cut pokemon series expect pay money game want ...   sword  negative
#
# [1349 rows x 6 columns]

# %%
vectorizer = CountVectorizer(stop_words=stop_words, ngram_range = (1,2),
                                   strip_accents = 'ascii', 
                                   token_pattern="\\b[a-z][a-z][a-z]+\\b")

# %%
doc_word = vectorizer.fit_transform(negative.review)
doc_word.shape
# Out:
# (1349, 28257)

# %%
pd.DataFrame(doc_word.toarray(), index=negative.review, columns=vectorizer.get_feature_names()).head(10)

# %% [markdown]
# ## LSA

# %%
lsa = TruncatedSVD(4)
doc_topic = lsa.fit_transform(doc_word)
lsa.explained_variance_ratio_
# Out:
# array([0.08216   , 0.02219374, 0.01460984, 0.01269882])

# %%
topic_word = pd.DataFrame(lsa.components_.round(3),
             index = ["component_1","component_2"],
             columns = vectorizer.get_feature_names())
topic_word

# %%
def display_topics(model, feature_names, no_top_words, topic_names=None):
    for ix, topic in enumerate(model.components_):
        if not topic_names or not topic_names[ix]:
            print("\nTopic ", ix)
        else:
            print("\nTopic: '",topic_names[ix],"'")
        print(", ".join([feature_names[i]
                        for i in topic.argsort()[:-no_top_words - 1:-1]]))

# %%
display_topics(lsa, vectorizer.get_feature_names(), 15)
# Out:
# Topic  0
# feel, battle, animation, area, time, look, story, cut, use, character, model, fan, feature, switch, thing
#
# Topic  1
# feel, area, battle, gym, story, route, fight, character, challenge, explore, catch, raid, level, tower, team
#
# Topic  2
# animation, battle, model, look, attack, texture, turn, model animation, tree, feel, overworld, mon, cutscene, animation model, world
#
# Topic  3
# feel, fan, world, franchise, gamefreak, lot, console, quality, entry, people, title, switch, design, freak, love

# %% [markdown]
# ### NMF

# %%
nmf_model = NMF(4)
doc_topic = nmf_model.fit_transform(doc_word)

# %%
topic_word = pd.DataFrame(nmf_model.components_.round(3),
             index = ["component_1","component_2"],
             columns = vectorizer.get_feature_names())
topic_word

# %%
display_topics(nmf_model, vectorizer.get_feature_names(), 15)
# Out:
# Topic  0
# area, gym, battle, story, character, catch, use, team, time, fight, route, level, point, problem, feature
#
# Topic  1
# fan, time, content, franchise, gamefreak, cut, switch, release, buy, graphic, sword, want, year, people, thing
#
# Topic  2
# animation, model, cut, look, turn, use, battle, graphic, quality, time, lie, let, gamefreak, lot, model animation
#
# Topic  3
# feel, battle, look, story, area, time, world, design, lack, lot, entry, player, explore, compare, music

# %% [markdown]
# ### LDA

# %%
vectorizer.fit(negative.review)
doc_word = vectorizer.transform(negative.review).transpose()

# %%
corpus = matutils.Sparse2Corpus(doc_word)

# %%
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
id2word = dict((v, k) for k, v in vectorizer.vocabulary_.items())

# %%
#lda = models.LdaModel(corpus=corpus, num_topics=3, id2word=id2word, passes=20)

lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=4, 
                                           random_state=77,
                                           update_every=1,
                                           chunksize=100,
                                           passes=50, iterations = 100,
                                           alpha='auto',
                                           per_word_topics=True)
# Out:
# 2019-11-29 17:04:21,199 : INFO : using autotuned alpha, starting with [0.25, 0.25, 0.25, 0.25]
# 2019-11-29 17:04:21,202 : INFO : using symmetric eta at 0.25
# 2019-11-29 17:04:21,218 : INFO : using serial LDA version on this node
# 2019-11-29 17:04:21,241 : INFO : running online (multi-pass) LDA training, 4 topics, 50 passes over the supplied corpus of 1349 documents, updating model once every 100 documents, evaluating perplexity every 1000 documents, iterating 100x with a convergence threshold of 0.001000
# 2019-11-29 17:04:21,246 : INFO : PROGRESS: pass 0, at document #100/1349
# 2019-11-29 17:04:21,572 : INFO : optimized alpha [0.19511163, 0.18055123, 0.25010082, 0.18264166]
# 2019-11-29 17:04:21,583 : INFO : merging changes from 100 documents into a model of 1349 documents
# 2019-11-29 17:04:21,595 : INFO : topic #0 (0.195): 0.007*"battle" + 0.005*"animation" + 0.004*"series" + 0.004*"story" + 0.004*"time" + 0.004*"gamefreak" + 0.004*"cut" + 0.004*"switch" + 0.004*"review" + 0.003*"feature"
# 2019-11-29 17:04:21,597 : INFO : topic #1 (0.181): 0.006*"story" + 0.005*"series" + 0.005*"fan" + 0.005*"animation" + 0.005*"battle" + 0.005*"time" + 0.004*"feel" + 0.004*"cut" + 0.004*"want" + 0.004*"gamefreak"
# 2019-11-29 17:04:21,602 : INFO : topic #2 (0.250): 0.009*"time" + 0.006*"area" + 0.006*"animation" + 0.005*"battle" + 0.005*"model" + 0.005*"franchise" + 0.005*"content" + 0.005*"issue" + 0.005*"story" + 0.005*"switch"
: INFO : merging changes from 100 documents into a model of 1349 documents
# 2019-11-29 17:04:29,969 : INFO : topic #0 (0.301): 0.008*"feel" + 0.005*"fan" + 0.004*"world" + 0.004*"gamefreak" + 0.004*"battle" + 0.004*"lot" + 0.004*"look" + 0.004*"year" + 0.004*"design" + 0.004*"people"
# 2019-11-29 17:04:29,971 : INFO : topic #1 (0.274): 0.012*"area" + 0.011*"battle" + 0.010*"feel" + 0.008*"story" + 0.008*"gym" + 0.006*"character" + 0.006*"design" + 0.005*"catch" + 0.005*"point" + 0.005*"time"
# 2019-11-29 17:04:29,977 : INFO : topic #2 (0.687): 0.010*"cut" + 0.009*"switch" + 0.009*"graphic" + 0.009*"time" + 0.008*"animation" + 0.007*"content" + 0.007*"gamefreak" + 0.007*"look" + 0.006*"franchise" + 0.006*"fan"
# 2019-11-29 17:04:29,985 : INFO : topic #3 (0.212): 0.014*"animation" + 0.009*"cut" + 0.009*"model" + 0.006*"remove" + 0.005*"lie" + 0.003*"reuse" + 0.003*"look" + 0.003*"use" + 0.003*"problem" + 0.003*"texture"
# 2019-11-29 17:04:29,990 : INFO : topic diff=0.320852, rho=0.246258
# 2019-11-29 17:04:29,995 : INFO : PROGRESS: pass 2, at document #900/1349
# 2019-11-29 17:04:30,106 : INFO : optimized alpha [0.29628196, 0.27401546, 0.7277147, 0.2123437]
# 2019-11-29 17:04:30,116 : INFO : merging changes from 100 documents into a model of 1349 documents
# 2019-11-29 17:04:30,128 : INFO : topic #0 (0.296): 0.007*"feel" + 0.005*"fan" + 0.005*"world" + 0.004*"gamefreak" + 0.004*"battle" + 0.004*"look" + 0.004*"year" + 0.004*"lot" + 0.004*"design" + 0.004*"people"
# 2019-11-29 17:04:30,136 : INFO : topic #1 (0.274): 0.011*"area" + 0.011*"battle" + 0.009*"feel" + 0.008*"story" + 0.007*"gym" + 0.006*"character" + 0.005*"design" + 0.005*"lack" + 0.005*"time" + 0.004*"look"
# 2019-11-29 17:04:30,143 : INFO : topic #2 (0.728): 0.010*"cut" + 0.010*"switch" + 0.009*"graphic" + 0.009*"animation" + 0.008*"time" + 0.008*"content" + 0.007*"look" + 0.007*"gamefreak" + 0.007*"franchise" + 0.006*"fan"
# 2019-11-29 17:04:30,150 : INFO : topic #3 (0.212): 0.015*"animation" + 0.009*"model" + 0.009*"cut" + 0.005*"remove" + 0.005*"lie" + 0.004*"reuse" + 0.003*"look" + 0.003*"texture" + 0.003*"use" + 0.003*"rate"
# 2019-11-29 17:04:30,153 : INFO : topic diff=0.319465, rho=0.246258
# 2019-11-29 17:04:30,430 : INFO : -10.142 per-word bound, 1130.3 perplexity estimate based on a held-out corpus of 100 documents with 7002 words
# 2019-11-29 17:04:30,431 : INFO : PROGRESS: pass 2, at document #1000/1349
# 2019-11-29 17:04:30,519 : INFO : optimized alpha [0.3131248, 0.27418557, 0.7592907, 0.21011432]
# 2019-11-29 17:04:30,529 : INFO : merging changes from 100 documents into a model of 1349 documents
# 2019-11-29 17:04
: INFO : merging changes from 100 documents into a model of 1349 documents
# 2019-11-29 17:05:49,873 : INFO : topic #0 (0.050): 0.002*"cash" + 0.002*"grab" + 0.002*"people" + 0.002*"garbage" + 0.001*"cash grab" + 0.001*"trust" + 0.001*"people buy" + 0.001*"management" + 0.001*"bit" + 0.001*"monster design"
# 2019-11-29 17:05:49,875 : INFO : topic #1 (0.139): 0.011*"battle" + 0.011*"area" + 0.010*"feel" + 0.007*"story" + 0.007*"gym" + 0.005*"character" + 0.005*"design" + 0.005*"look" + 0.005*"time" + 0.004*"route"
# 2019-11-29 17:05:49,877 : INFO : topic #2 (0.637): 0.012*"animation" + 0.009*"cut" + 0.008*"graphic" + 0.008*"fan" + 0.007*"look" + 0.007*"time" + 0.007*"switch" + 0.007*"gamefreak" + 0.006*"model" + 0.006*"content"
# 2019-11-29 17:05:49,879 : INFO : topic #3 (0.035): 0.001*"lock" + 0.001*"animate" + 0.001*"force" + 0.001*"cutting" + 0.001*"attack" + 0.001*"screen" + 0.001*"help" + 0.001*"spin" + 0.001*"reuse" + 0.001*"trade"
# 2019-11-29 17:05:49,881 : INFO : topic diff=0.106246, rho=0.125501
# 2019-11-29 17:05:49,886 : INFO : PROGRESS: pass 49, at document #300/1349
# 2019-11-29 17:05:49,933 : INFO : optimized alpha [0.049631268, 0.13704173, 0.65520954, 0.03479156]
# 2019-11-29 17:05:49,941 : INFO : merging changes from 100 documents into a model of 1349 documents
# 2019-11-29 17:05:49,950 : INFO : topic #0 (0.050): 0.002*"cash" + 0.002*"grab" + 0.002*"garbage" + 0.001*"cash grab" + 0.001*"people" + 0.001*"people buy" + 0.001*"trust" + 0.001*"bit" + 0.001*"management" + 0.001*"nature"
# 2019-11-29 17:05:49,952 : INFO : topic #1 (0.137): 0.012*"battle" + 0.011*"feel" + 0.010*"area" + 0.007*"story" + 0.007*"gym" + 0.005*"character" + 0.005*"design" + 0.005*"look" + 0.005*"time" + 0.004*"route"
# 2019-11-29 17:05:49,955 : INFO : topic #2 (0.655): 0.011*"animation" + 0.009*"cut" + 0.008*"graphic" + 0.008*"fan" + 0.007*"look" + 0.007*"time" + 0.007*"switch" + 0.006*"gamefreak" + 0.006*"content" + 0.006*"model"
# 2019-11-29 17:05:49,957 : INFO : topic #3 (0.035): 0.001*"lock" + 0.001*"size" + 0.001*"animate" + 0.001*"force" + 0.001*"cutting" + 0.001*"help" + 0.001*"attack" + 0.001*"spin" + 0.001*"screen" + 0.001*"frame"
# 2019-11-29 17:05:49,958 : INFO : topic diff=0.087985, rho=0.125501
# 2019-11-29 17:05:49,963 : INFO : PROGRESS: pass 49, at document #400/1349
# 2019-11-29 17:05:50,004 : INFO : optimized alpha [0.049970504, 0.13551515, 0.66512835, 0.03495664]
# 2019-11-29 17:05:50,012 : INFO : merging changes from 100 documents into a model of 1349 documents
# 2019-11-29 17:05:50,020 : INFO : topic #0 (0.050): 0.002*"cash" + 0.002*"grab" + 0.002*"garbage" + 0.002*"cash grab" + 0.001*"people" + 0.001*"trust" + 0.001*"people buy" + 0.001*"bit" + 0.001*"starter" + 0.001*"quality content"
# 2019-11-29 17:05:50,022 : INFO : topic #1 (0.136): 0.011*"battle" + 0.011*"feel" + 0.010*"area" + 0.007*"story" + 0.007*"gym" + 0.005*"character" + 0.005*"look" + 0.005*"design" + 0.004*"time" + 0.004*"lack"
# 2019-11-29 17:05:50,024 : INFO : topic #2 (0.665): 0.012*"animation" + 0.009*"cut" + 0.008*"graphic" + 0.008*"fan" + 0.007*"look" + 0.007*"switch" + 0.007*"time" + 0.007*"gamefreak" + 0.006*"model" + 0.006*"content"
# 2019-11-29 17:05:50,026 : INFO : topic #3 (0.035): 0.001*"lock" + 0.001*"size" + 0.001*"reuse" + 0.001*"force" + 0.001*"frame" + 0.001*"animate" + 0.001*"suffer" + 0.001*"screen" + 0.001*"cutting" + 0.001*"help"
# 2019-11-29 17:05:50,028 : INFO : topic diff=0.075877, rho=0.125501
# 2019-11-29 17:05:50,033 : INFO : PROGRESS: pass 49, at document #500/1349
# 2019-11-29 17:05:50,081 : INFO : optimized alpha [0.050142493, 0.1380548, 0.65102273, 0.034797244]
# 2019-11-29 17:05:50,089 : INFO : merging changes from 100 documents into a model of 1349 documents
# 2019-11-29 17:05:50,098 : INFO : topic #0 (0.050): 0.002*"cash" + 0.002*"garbage" + 0.002*"grab" + 0.001*"cash grab" + 0.001*"people" + 0.001*"management" + 0.001*"trust" + 0.001*"world section" + 0.001*"people buy" + 0.001*"bit"
# 2019-11-29 17:05:50,101 : INFO : topic #1 (0.138): 0.011*"feel" + 0.011*"battle" + 0.011*"area" + 0.008*"story" + 0.007*"gym" + 0.006*"character" + 0.005*"look" + 0.005*"design" + 0.004*"time" + 0.004*"lack"
# 2019-11-29 17:05:50,103 : INFO : topic #2 (0.651): 0.012*"animation" + 0.009*"cut" + 0.009*"graphic" + 0.007*"fan" + 0.007*"look" + 0.007*"time" + 0.007*"switch" + 0.007*"gamefreak" + 0.006*"model" + 0.006*"content"
# 2019-11-29 17:05:50,105 : INFO : topic #3 (0.035): 0.001*"lock" + 0.001*"screen" + 0.001*"frame" + 0.001*"suffer" + 0.001*"reuse" + 0.001*"size" + 0.001*"spin" + 0.001*"asset" + 0.001*"force" + 0.001*"attack"
# 2019-11-29 17:05:50,107 : INFO : topic diff=0.104649, rho=0.125501
# 2019-11-29 17:05:50,112 : INFO : PROGRESS: pass 49, at document #600/1349
# 2019-11-29 17:05:50,179 : INFO : optimized alpha [0.04983328, 0.1395985, 0.65955204, 0.03455618]
# 2019-11-29 17:05:50,186 : INFO : merging changes from 100 documents into a model of 1349 documents
# 2019-11-29 17:05:50,194 : INFO : topic #0 (0.050): 0.002*"cash" + 0.001*"garbage" + 0.001*"grab" + 0.001*"people" + 0.001*"cash grab" + 0.001*"trust" + 0.001*"management" + 0.001*"starter" + 0.001*"world section" + 0.001*"people buy"
# 2019-11-29 17:05:50,196 : INFO : topic #1 (0.140): 0.011*"feel" + 0.011*"area" + 0.011*"battle" + 0.008*"story" + 0.007*"gym" + 0.005*"design" + 0.005*"character" + 0.005*"look" + 0.005*"time" + 0.004*"route"
# 2019-11-29 17:05:50,198 : INFO : topic #2 (0.660): 0.011*"animation" + 0.010*"cut" + 0.009*"graphic" + 0.007*"time" + 0.007*"look" + 0.007*"fan" + 0.007*"gamefreak" + 0.007*"switch" + 0.006*"model" + 0.006*"content"
# 2019-11-29 17:05:50,201 : INFO : topic #3 (0.035): 0.001*"lock" + 0.001*"frame" + 0.001*"screen" + 0.001*"reuse" + 0.001*"suffer" + 0.001*"size" + 0.001*"spin" + 0.001*"asset" + 0.001*"force" + 0.001*"attack"
# 2019-11-29 17:05:50,202 : INFO : topic diff=0.094726, rho=0.125501
# 2019-11-29 17:05:50,207 : INFO : PROGRESS: pass 49, at document #700/1349
# 2019-11-29 17:05:50,261 : INFO : optimized alpha [0.049273297, 0.14188577, 0.65687275, 0.034942977]
# 2019-11-29 17:05:50,269 : INFO : merging changes from 100 documents into a model of 1349 documents
# 2019-11-29 17:05:50,278 : INFO : topic #0 (0.049): 0.002*"cash" + 0.001*"garbage" + 0.001*"grab" + 0.001*"cash grab" + 0.001*"people" + 0.001*"trust" + 0.001*"management" + 0.001*"starter" + 0.001*"nature" + 0.001*"million"
# 2019-11-29 17:05:50,280 : INFO : topic #1 (0.142): 0.011*"feel" + 0.011*"area" + 0.011*"battle" + 0.007*"story" + 0.007*"gym" + 0.005*"design" + 0.005*"look" + 0.005*"character" + 0.005*"time" + 0.004*"lack"
# 2019-11-29 17:05:50,282 : INFO : topic #2 (0.657): 0.012*"animation" + 0.010*"cut" + 0.009*"graphic" + 0.007*"fan" + 0.007*"look" + 0.007*"time" + 0.007*"gamefreak" + 0.007*"switch" + 0.006*"model" + 0.006*"content"
# 2019-11-29 17:05:50,284 : INFO : topic #3 (0.035): 0.001*"spin" + 0.001*"lock" + 0.001*"screen" + 0.001*"size" + 0.001*"pikachu" + 0.001*"animate" + 0.001*"help" + 0.001*"suffer" + 0.001*"frame" + 0.001*"reuse"
# 2019-11-29 17:05:50,287 : INFO : topic diff=0.106714, rho=0.125501
# 2019-11-29 17:05:50,292 : INFO : PROGRESS: pass 49, at document #800/1349
# 2019-11-29 17:05:50,346 : INFO : optimized alpha [0.049959466, 0.13988374, 0.667454, 0.034869518]
# 2019-11-29 17:05:50,354 : INFO : merging changes from 100 documents into a model of 1349 documents
# 2019-11-29 17:05:50,362 : INFO : topic #0 (0.050): 0.002*"cash" + 0.002*"grab" + 0.002*"cash grab" + 0.001*"garbage" + 0.001*"people" + 0.001*"million" + 0.001*"trust" + 0.001*"bit" + 0.001*"management" + 0.001*"starter"
# 2019-11-29 17:05:50,364 : INFO : topic #1 (0.140): 0.011*"area" + 0.011*"feel" + 0.011*"battle" + 0.007*"gym" + 0.007*"story" + 0.005*"design" + 0.005*"character" + 0.005*"look" + 0.005*"time" + 0.004*"route"
# 2019-11-29 17:05:50,366 : INFO : topic #2 (0.667): 0.012*"animation" + 0.010*"cut" + 0.009*"graphic" + 0.007*"time" + 0.007*"look" + 0.007*"fan" + 0.007*"gamefreak" + 0.007*"switch" + 0.006*"model" + 0.006*"content"
# 2019-11-29 17:05:50,369 : INFO : topic #3 (0.035): 0.001*"screen" + 0.001*"force" + 0.001*"action" + 0.001*"spin" + 0.001*"asset" + 0.001*"size" + 0.001*"animate" + 0.001*"lock" + 0.001*"help" + 0.001*"frame"
# 2019-11-29 17:05:50,371 : INFO : topic diff=0.099569, rho=0.125501
# 2019-11-29 17:05:50,375 : INFO : PROGRESS: pass 49, at document #900/1349
# 2019-11-29 17:05:50,428 : INFO : optimized alpha [0.04986732, 0.13725404, 0.6780619, 0.034865562]
# 2019-11-29 17:05:50,436 : INFO : merging changes from 100 documents into a model of 1349 documents
# 2019-11-29 17:05:50,444 : INFO : topic #0 (0.050): 0.002*"cash" + 0.002*"grab" + 0.001*"cash grab" + 0.001*"garbage" + 0.001*"people" + 0.001*"million" + 0.001*"management" + 0.001*"trust" + 0.001*"bit" + 0.001*"starter"
# 2019-11-29 17:05:50,446 : INFO : topic #1 (0.137): 0.011*"battle" + 0.011*"area" + 0.010*"feel" + 0.007*"story" + 0.007*"gym" + 0.005*"design" + 0.005*"character" + 0.005*"look" + 0.004*"time" + 0.004*"lack"
# 2019-11-29 17:05:50,448 : INFO : topic #2 (0.678): 0.012*"animation" + 0.010*"cut" + 0.009*"graphic" + 0.007*"look" + 0.007*"fan" + 0.007*"time" + 0.007*"switch" + 0.007*"gamefreak" + 0.006*"model" + 0.006*"content"
# 2019-11-29 17:05:50,450 : INFO : topic #3 (0.035): 0.001*"spin" + 0.001*"attack" + 0.001*"animate" + 0.001*"screen" + 0.001*"force" + 0.001*"action" + 0.001*"help" + 0.001*"asset" + 0.001*"size" + 0.001*"lock"
# 2019-11-29 17:05:50,452 : INFO : topic diff=0.097050, rho=0.125501
# 2019-11-29 17:05:50,618 : INFO : -9.482 per-word bound, 715.1 perplexity estimate based on a held-out corpus of 100 documents with 7002 words
# 2019-11-29 17:05:50,619 : INFO : PROGRESS: pass 49, at document #1000/1349
# 2019-11-29 17:05:50,667 : INFO : optimized alpha [0.050188262, 0.13778797, 0.6829077, 0.034622364]
# 2019-11-29 17:05:50,675 : INFO : merging changes from 100 documents into a model of 1349 documents
# 2019-11-29 17:05:50,683 : INFO : topic #0 (0.050): 0.002*"cash" + 0.002*"grab" + 0.002*"cash grab" + 0.001*"garbage" + 0.001*"people" + 0.001*"starter" + 0.001*"trust" + 0.001*"bit" + 0.001*"million" + 0.001*"management"
# 2019-11-29 17:05:50,685 : INFO : topic #1 (0.138): 0.011*"area" + 0.010*"battle" + 0.010*"feel" + 0.007*"story" + 0.007*"gym" + 0.005*"design" + 0.005*"character" + 0.005*"time" + 0.004*"look" + 0.004*"route"
# 2019-11-29 17:05:50,687 : INFO : topic #2 (0.683): 0.012*"animation" + 0.010*"cut" + 0.009*"graphic" + 0.007*"time" + 0.007*"fan" + 0.007*"look" + 0.007*"switch" + 0.007*"gamefreak" + 0.006*"model" + 0.006*"franchise"
# 2019-11-29 17:05:50,691 : INFO : topic #3 (0.035): 0.001*"help" + 0.001*"attack" + 0.001*"spin" + 0.001*"animate" + 0.001*"screen" + 0.001*"asset" + 0.001*"force" + 0.001*"frame" + 0.001*"action" + 0.001*"size"
# 2019-11-29 17:05:50,693 : INFO : topic diff=0.116141, rho=0.125501
# 2019-11-29 17:05:50,698 : INFO : PROGRESS: pass 49, at document #1100/1349
# 2019-11-29 17:05:50,747 : INFO : optimized alpha [0.049954113, 0.13649464, 0.6870185, 0.03474512]
# 2019-11-29 17:05:50,754 : INFO : merging changes from 100 documents into a model of 1349 documents
# 2019-11-29 17:05:50,764 : INFO : topic #0 (0.050): 0.002*"cash" + 0.002*"grab" + 0.002*"cash grab" + 0.001*"people" + 0.001*"garbage" + 0.001*"trust" + 0.001*"people buy" + 0.001*"starter" + 0.001*"bit" + 0.001*"million"
# 2019-11-29 17:05:50,766 : INFO : topic #1 (0.136): 0.011*"area" + 0.011*"battle" + 0.010*"feel" + 0.007*"story" + 0.006*"gym" + 0.005*"design" + 0.005*"character" + 0.005*"route" + 0.005*"time" + 0.004*"look"
# 2019-11-29 17:05:50,768 : INFO : topic #2 (0.687): 0.012*"animation" + 0.010*"cut" + 0.009*"graphic" + 0.007*"fan" + 0.007*"time" + 0.007*"look" + 0.007*"gamefreak" + 0.007*"switch" + 0.006*"model" + 0.006*"content"
# 2019-11-29 17:05:50,770 : INFO : topic #3 (0.035): 0.001*"spin" + 0.001*"asset" + 0.001*"help" + 0.001*"attack" + 0.001*"animate" + 0.001*"screen" + 0.001*"suffer" + 0.001*"force" + 0.001*"action" + 0.001*"frame"
# 2019-11-29 17:05:50,772 : INFO : topic diff=0.115000, rho=0.125501
# 2019-11-29 17:05:50,778 : INFO : PROGRESS: pass 49, at document #1200/1349
# 2019-11-29 17:05:50,828 : INFO : optimized alpha [0.050307564, 0.13608176, 0.691978, 0.034561742]
# 2019-11-29 17:05:50,836 : INFO : merging changes from 100 documents into a model of 1349 documents
# 2019-11-29 17:05:50,845 : INFO : topic #0 (0.050): 0.002*"cash" + 0.002*"grab" + 0.002*"cash grab" + 0.001*"garbage" + 0.001*"people" + 0.001*"people buy" + 0.001*"trust" + 0.001*"bit" + 0.001*"starter" + 0.001*"wallet"
# 2019-11-29 17:05:50,847 : INFO : topic #1 (0.136): 0.011*"area" + 0.010*"battle" + 0.010*"feel" + 0.006*"gym" + 0.006*"story" + 0.005*"character" + 0.005*"time" + 0.005*"design" + 0.005*"look" + 0.004*"route"
# 2019-11-29 17:05:50,848 : INFO : topic #2 (0.692): 0.012*"animation" + 0.010*"cut" + 0.009*"graphic" + 0.008*"fan" + 0.007*"look" + 0.007*"time" + 0.007*"switch" + 0.007*"gamefreak" + 0.006*"model" + 0.006*"franchise"
# 2019-11-29 17:05:50,851 : INFO : topic #3 (0.035): 0.001*"spin" + 0.001*"asset" + 0.001*"help" + 0.001*"suffer" + 0.001*"attack" + 0.001*"animate" + 0.001*"action" + 0.001*"lock" + 0.001*"screen" + 0.001*"force"
# 2019-11-29 17:05:50,852 : INFO : topic diff=0.104006, rho=0.125501
# 2019-11-29 17:05:50,857 : INFO : PROGRESS: pass 49, at document #1300/1349
# 2019-11-29 17:05:50,907 : INFO : optimized alpha [0.04981085, 0.1375516, 0.66456836, 0.03459704]
# 2019-11-29 17:05:50,915 : INFO : merging changes from 100 documents into a model of 1349 documents
# 2019-11-29 17:05:50,923 : INFO : topic #0 (0.050): 0.002*"cash" + 0.002*"grab" + 0.001*"garbage" + 0.001*"cash grab" + 0.001*"people" + 0.001*"people buy" + 0.001*"trust" + 0.001*"management" + 0.001*"starter" + 0.001*"bit"
# 2019-11-29 17:05:50,925 : INFO : topic #1 (0.138): 0.011*"area" + 0.011*"battle" + 0.010*"feel" + 0.007*"gym" + 0.006*"story" + 0.005*"character" + 0.005*"time" + 0.005*"design" + 0.004*"route" + 0.004*"lack"
# 2019-11-29 17:05:50,927 : INFO : topic #2 (0.665): 0.012*"animation" + 0.010*"cut" + 0.009*"graphic" + 0.007*"fan" + 0.007*"look" + 0.007*"time" + 0.007*"switch" + 0.007*"gamefreak" + 0.006*"model" + 0.006*"content"
# 2019-11-29 17:05:50,929 : INFO : topic #3 (0.035): 0.001*"screen" + 0.001*"lock" + 0.001*"spin" + 0.001*"animate" + 0.001*"help" + 0.001*"asset" + 0.001*"frame" + 0.001*"action" + 0.001*"force" + 0.001*"suffer"
# 2019-11-29 17:05:50,931 : INFO : topic diff=0.101423, rho=0.125501
# 2019-11-29 17:05:51,031 : INFO : -9.204 per-word bound, 589.9 perplexity estimate based on a held-out corpus of 49 documents with 3663 words
# 2019-11-29 17:05:51,032 : INFO : PROGRESS: pass 49, at document #1349/1349
# 2019-11-29 17:05:51,072 : INFO : optimized alpha [0.04950982, 0.13872924, 0.61734104, 0.03399955]
# 2019-11-29 17:05:51,080 : INFO : merging changes from 49 documents into a model of 1349 documents
# 2019-11-29 17:05:51,088 : INFO : topic #0 (0.050): 0.002*"cash" + 0.002*"grab" + 0.001*"cash grab" + 0.001*"people" + 0.001*"garbage" + 0.001*"trust" + 0.001*"monster design" + 0.001*"people buy" + 0.001*"experience satisfy" + 0.001*"gimmick try"
# 2019-11-29 17:05:51,090 : INFO : topic #1 (0.139): 0.011*"area" + 0.011*"feel" + 0.010*"battle" + 0.007*"story" + 0.007*"gym" + 0.005*"design" + 0.005*"character" + 0.005*"look" + 0.005*"time" + 0.004*"lack"
# 2019-11-29 17:05:51,092 : INFO : topic #2 (0.617): 0.012*"animation" + 0.009*"cut" + 0.009*"graphic" + 0.008*"fan" + 0.008*"look" + 0.007*"time" + 0.007*"switch" + 0.006*"gamefreak" + 0.006*"content" + 0.006*"franchise"
# 2019-11-29 17:05:51,094 : INFO : topic #3 (0.034): 0.001*"meta" + 0.001*"screen" + 0.001*"lock" + 0.001*"spin" + 0.001*"animate" + 0.001*"frame" + 0.001*"help" + 0.001*"force" + 0.001*"asset" + 0.001*"render"
# 2019-11-29 17:05:51,096 : INFO : topic diff=0.105809, rho=0.125501

# %%
lda_model.print_topics()
# Out:
# 2019-11-29 17:05:51,106 : INFO : topic #0 (0.050): 0.002*"cash" + 0.002*"grab" + 0.001*"cash grab" + 0.001*"people" + 0.001*"garbage" + 0.001*"trust" + 0.001*"monster design" + 0.001*"people buy" + 0.001*"experience satisfy" + 0.001*"gimmick try"
# 2019-11-29 17:05:51,108 : INFO : topic #1 (0.139): 0.011*"area" + 0.011*"feel" + 0.010*"battle" + 0.007*"story" + 0.007*"gym" + 0.005*"design" + 0.005*"character" + 0.005*"look" + 0.005*"time" + 0.004*"lack"
# 2019-11-29 17:05:51,111 : INFO : topic #2 (0.617): 0.012*"animation" + 0.009*"cut" + 0.009*"graphic" + 0.008*"fan" + 0.008*"look" + 0.007*"time" + 0.007*"switch" + 0.006*"gamefreak" + 0.006*"content" + 0.006*"franchise"
# 2019-11-29 17:05:51,114 : INFO : topic #3 (0.034): 0.001*"meta" + 0.001*"screen" + 0.001*"lock" + 0.001*"spin" + 0.001*"animate" + 0.001*"frame" + 0.001*"help" + 0.001*"force" + 0.001*"asset" + 0.001*"render"
# [(0,
#   '0.002*"cash" + 0.002*"grab" + 0.001*"cash grab" + 0.001*"people" + 0.001*"garbage" + 0.001*"trust" + 0.001*"monster design" + 0.001*"people buy" + 0.001*"experience satisfy" + 0.001*"gimmick try"'),
#  (1,
#   '0.011*"area" + 0.011*"feel" + 0.010*"battle" + 0.007*"story" + 0.007*"gym" + 0.005*"design" + 0.005*"character" + 0.005*"look" + 0.005*"time" + 0.004*"lack"'),
#  (2,
#   '0.012*"animation" + 0.009*"cut" + 0.009*"graphic" + 0.008*"fan" + 0.008*"look" + 0.007*"time" + 0.007*"switch" + 0.006*"gamefreak" + 0.006*"content" + 0.006*"franchise"'),
#  (3,
#   '0.001*"meta" + 0.001*"screen" + 0.001*"lock" + 0.001*"spin" + 0.001*"animate" + 0.001*"frame" + 0.001*"help" + 0.001*"force" + 0.001*"asset" + 0.001*"render"')]

# %%
vectorizer.vocabulary_.items()
